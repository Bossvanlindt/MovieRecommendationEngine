# %% [markdown]
# # ChromaDB Guide & Poopulation with Kaggle Data
# This notebook creates the locally-persisted ChromaDB (in /inference/chromadb) if it doesn't yet exist, creates the movie collection, and adds in the data from the catalogue that is in the Kaggle dataset.
#
# Note: we opt for the default distance function (squared L2 norm) and embedding function (Sentence Embedding). If these are changed, we must ensure that this script is run again after we clear the chromadb to reflect that.

# %%
import chromadb
import pandas as pd
import json
import time

# %%
# Connect to our locally-persisted chromadb
client = chromadb.PersistentClient(path="../inference/chromadb/")

# %%
# Chroma uses Sentence Embedding model by default, but can change this here
# Also, it by default uses squared L2 norm as the distance function. To change, see: https://docs.trychroma.com/usage-guide#changing-the-distance-function
movies = client.get_or_create_collection(name="movies")

# %%
# Test to add with just embedding and id
movies.add(
    embeddings=[1 for _ in range(384)],
    ids=["test_id"]
)

# %%
movies.query(
    query_embeddings=[1 for _ in range(384)],
    n_results=1
)
# Out:
# {'ids': [['test_id']],
#  'distances': [[0.0]],
#  'metadatas': [[None]],
#  'embeddings': None,
#  'documents': [[None]]}

# %%
# Gets the first 10 elements
movies.peek()
# Gets size
movies.count()
# Out:
# 17618

# %% [markdown]
# ## Add Kaggle data into ChromaDB
#
# We currently pass it in as strings of jsons with the structure and all. Documentation says it can take in documents, but doesn't work with dictionaries it seems.
#
# Time to embed and save: 13:31 mins for the 17618 documents = 0.0460324668 seconds / embedding. Very quick!
#
# Averages roughly 0.045 seconds per query

# %%
# Load the comp585_movies.csv dataset
df = pd.read_csv("./kaggle_dataset/comp585_movies.csv")

# %%
df.head(2)
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
#
#                                homepage    id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story   862  tt0114709                en
# 1                                   NaN  8844  tt0113497                en
#
#   original_title                                           overview  ...  \
# 0      Toy Story  Led by Woody, Andy's toys live happily in his ...  ...
# 1        Jumanji  When siblings Judy and Peter discover an encha...  ...
#
#        revenue runtime                                   spoken_languages  \
# 0  373554033.0    81.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1  262797249.0   104.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
#
#      status                                    tagline      title  video  \
# 0  Released                                        NaN  Toy Story  False
# 1  Released  Roll the dice and unleash the excitement!    Jumanji  False
#
#   vote_average vote_count        movie_id
# 0          7.7     5415.0  toy+story+1995
# 1          6.9     2413.0    jumanji+1995
#
# [2 rows x 25 columns]

# %%
# Delete any duplicate rows based on movie_id
df = df.drop_duplicates(subset=['movie_id'])

# %%
# Format it properly
jsons = df.to_dict(orient='records')
jsons = [str(j) for j in jsons]
# Get the ids
ids = df['movie_id'].tolist()

# %%
"""
As documents, we pass in the entire row as a string of JSON document
As ids, we pass in the movie_id field

List of fields: adult,belongs_to_collection,budget,genres,homepage,id,imdb_id,original_language,original_title,overview,popularity,poster_path,production_companies,production_countries,release_date,revenue,runtime,spoken_languages,status,tagline,title,video,vote_average,vote_count,movie_id
API gives us the same fields, so course likely just uses Kaggle dataset as its source

This then automatically calculates embeddings from the documents and stores them in the database.
"""
movies.add(
  documents = jsons,
  ids = ids
)
# Out:
# Insert of existing embedding ID: toy+story+1995
# Insert of existing embedding ID: jumanji+1995
# Insert of existing embedding ID: grumpier+old+men+1995
# Insert of existing embedding ID: waiting+to+exhale+1995
# Insert of existing embedding ID: father+of+the+bride+part+ii+1995
# Insert of existing embedding ID: heat+1995
# Insert of existing embedding ID: sabrina+1995
# Insert of existing embedding ID: tom+and+huck+1995
# Insert of existing embedding ID: sudden+death+1995
# Insert of existing embedding ID: goldeneye+1995
# Insert of existing embedding ID: the+american+president+1995
# Insert of existing embedding ID: balto+1995
# Insert of existing embedding ID: nixon+1995
# Insert of existing embedding ID: cutthroat+island+1995
# Insert of existing embedding ID: casino+1995
# Insert of existing embedding ID: sense+and+sensibility+1995
# Insert of existing embedding ID: four+rooms+1995
# Insert of existing embedding ID: money+train+1995
# Insert of existing embedding ID: get+shorty+1995
# Insert of existing embedding ID: copycat+1995
# Insert of existing embedding ID: assassins+1995
# Insert of existing embedding ID: powder+1995
# Insert of existing embedding ID: leaving+las+vegas+1995
# Insert of existing embedding ID: othello+1995
# Insert of existing embedding ID: now+and+then+1995
# Insert of existing embedding ID: persuasion+1995
# Insert of existing embedding ID: dangerous+minds+1995
# Insert of existing embedding ID: twelve+monkeys+1995
# Insert of existing embedding ID: babe+1995
# Insert of existing embedding ID: carrington+1995
# Insert of existing embedding ID: dead+man+walking+1995
# Insert of existing embedding ID: across+the+sea+of+time+1995
# Insert of existing embedding ID: it+takes+two+1995
# Insert of existing embedding ID: clueless+1995
# Insert of existing embedding ID: richard+iii+1995
# Insert of existing embedding ID: dead+presidents+1995
# Insert of existing embedding ID: restoration+1995
# Insert of existing embedding ID: mortal+kombat+1995
# Insert of existing embedding ID: to+die+for+1995
# Insert of existing embedding ID: how+to+make+an+american+quilt+1995
# Insert of existing embedding ID: se7en+1995
# Insert of existing embedding ID: pocahontas+1995
# Insert of existing embedding ID: when+night+is+falling+1995
# Insert of existing embedding ID: the+usual+suspects+1995
# Insert of existing embedding ID: guardian+angel+1994
# Insert of existing embedding ID: mighty+aphrodite+1995
# Insert of existing embedding ID: lamerica+1994
# Insert of existing embedding ID: the+big+green+1995
# Insert of existing embedding ID: georgia+1995
# Insert of existing embedding ID: kids+of+the+round+table+1997
# Insert of existing embedding ID: home+for+the+holidays+1995
# Insert of existing embedding ID: the+indian+in+the+cupboard+1995
# Insert of existing embedding ID: eye+for+an+eye+1996
# Insert of existing embedding ID: two+if+by+sea+1996
# Insert of existing embedding ID: bio-dome+1996
# Insert of existing embedding ID: two+bits+1995
# Insert of existing embedding ID: friday+1995
# Insert of existing embedding ID: from+dusk+till+dawn+1996
# Insert of existing embedding ID: fair+game+1995
# Insert of existing embedding ID: kicking+and+screaming+1995
# Insert of existing embedding ID: bed+of+roses+1996
# Insert of existing embedding ID: big+bully+1996
# Insert of existing embedding ID: screamers+1995
# Insert of existing embedding ID: nico+icon+1995
# Insert of existing embedding ID: the+crossing+guard+1995
# Insert of existing embedding ID: the+juror+1996
# Insert of existing embedding ID: once+upon+a+time...+when+we+were+colored+1996
# Insert of existing embedding ID: last+summer+in+the+hamptons+1995
# Insert of existing embedding ID: angels+and+insects+1995
# Insert of existing embedding ID: white+squall+1996
# Insert of existing embedding ID: dunston+checks+in+1996
# Insert of existing embedding ID: black+sheep+1996
# Insert of existing embedding ID: nick+of+time+1995
# Insert of existing embedding ID: the+journey+of+august+king+1995
# Insert of existing embedding ID: mary+reilly+1996
# Insert of existing embedding ID: vampire+in+brooklyn+1995
# Insert of existing embedding ID: beautiful+girls+1996
# Insert of existing embedding ID: broken+arrow+1996
# Insert of existing embedding ID: la+haine+1995
# Insert of existing embedding ID: shopping+1994
# Insert of existing embedding ID: city+hall+1996
# Insert of existing embedding ID: bottle+rocket+1996
# Insert of existing embedding ID: mr.+wrong+1996
# Insert of existing embedding ID: unforgettable+1996
# Insert of existing embedding ID: happy+gilmore+1996
# Insert of existing embedding ID: the+bridges+of+madison+county+1995
# Insert of existing embedding ID: muppet+treasure+island+1996
# Insert of existing embedding ID: catwalk+1995
# Insert of existing embedding ID: headless+body+in+topless+bar+1995
# Insert of existing embedding ID: braveheart+1995
# Insert of existing embedding ID: taxi+driver+1976
# Insert of existing embedding ID: before+and+after+1996
# Insert of existing embedding ID: anne+frank+remembered+1995
# Insert of existing embedding ID: if+lucy+fell+1996
# Insert of existing embedding ID: steal+big+steal+little+1995
# Insert of existing embedding ID: race+the+sun+1996
# Insert of existing embedding ID: the+boys+of+st.+vincent+1992
# Insert of existing embedding ID: boomerang+1992
# Insert of existing embedding ID: flirting+with+disaster+1996
# Insert of existing embedding ID: pie+in+the+sky+1996
# Insert of existing embedding ID: angela+1995
# Insert of existing embedding ID: frankie+starlight+1995
# Insert of existing embedding ID: jade+1995
# Insert of existing embedding ID: nueba+yol+1995
# Insert of existing embedding ID: sonic+outlaws+1995
# Insert of existing embedding ID: down+periscope+1996
# Insert of existing embedding ID: from+the+journals+of+jean+seberg+1995
# Insert of existing embedding ID: man+of+the+year+1995
# Insert of existing embedding ID: the+neon+bible+1995
# Insert of existing embedding ID: target+1995
# Insert of existing embedding ID: the+birdcage+1996
# Insert of existing embedding ID: the+brothers+mcmullen+1995
# Insert of existing embedding ID: bad+boys+1995
# Insert of existing embedding ID: the+amazing+panda+adventure+1995
# Insert of existing embedding ID: the+basketball+diaries+1995
# Insert of existing embedding ID: an+awfully+big+adventure+1995
# Insert of existing embedding ID: amateur+1994
# Insert of existing embedding ID: apollo+13+1995
# Insert of existing embedding ID: rob+roy+1995
# Insert of existing embedding ID: the+addiction+1995
# Insert of existing embedding ID: batman+forever+1995
# Insert of existing embedding ID: belle+de+jour+1967
# Insert of existing embedding ID: beyond+rangoon+1995
# Insert of existing embedding ID: blue+in+the+face+1995
# Insert of existing embedding ID: canadian+bacon+1995
# Insert of existing embedding ID: casper+1995
# Insert of existing embedding ID: clockers+1995
# Insert of existing embedding ID: congo+1995
# Insert of existing embedding ID: crimson+tide+1995
# Insert of existing embedding ID: crumb+1994
# Insert of existing embedding ID: desperado+1995
# Insert of existing embedding ID: devil+in+a+blue+dress+1995
# Insert of existing embedding ID: the+doom+generation+1995
# Insert of existing embedding ID: feast+of+july+1995
# Insert of existing embedding ID: first+knight+1995
# Insert of existing embedding ID: free+willy+2+-+the+adventure+home+1995
# Insert of existing embedding ID: hackers+1995
# Insert of existing embedding ID: jeffrey+1995
# Insert of existing embedding ID: johnny+mnemonic+1995
# Insert of existing embedding ID: judge+dredd+1995
# Insert of existing embedding ID: jury+duty+1995
# Insert of existing embedding ID: kids+1995
# Insert of existing embedding ID: living+in+oblivion+1995
# Insert of existing embedding ID: lord+of+illusions+1995
# Insert of existing embedding ID: mad+love+1995
# Insert of existing embedding ID: mallrats+1995
# Insert of existing embedding ID: moonlight+and+valentino+1995
# Insert of existing embedding ID: mute+witness+1995
# Insert of existing embedding ID: nadja+1994
# Insert of existing embedding ID: the+net+1995
# Insert of existing embedding ID: nine+months+1995
# Insert of existing embedding ID: party+girl+1995
# Insert of existing embedding ID: the+prophecy+1995
# Insert of existing embedding ID: reckless+1995
# Insert of existing embedding ID: safe+1995
# Insert of existing embedding ID: the+scarlet+letter+1995
# Insert of existing embedding ID: the+show+1995
# Insert of existing embedding ID: showgirls+1995
# Insert of existing embedding ID: smoke+1995
# Insert of existing embedding ID: something+to+talk+about+1995
# Insert of existing embedding ID: species+1995
# Insert of existing embedding ID: the+stars+fell+on+henrietta+1995
# Insert of existing embedding ID: strange+days+1995
# Insert of existing embedding ID: the+tie+that+binds+1995
# Insert of existing embedding ID: three+wishes+1995
# Insert of existing embedding ID: total+eclipse+1995
# Insert of existing embedding ID: unstrung+heroes+1995
# Insert of existing embedding ID: unzipped+1995
# Insert of existing embedding ID: a+walk+in+the+clouds+1995
# Insert of existing embedding ID: waterworld+1995
# Insert of existing embedding ID: wild+bill+1995
# Insert of existing embedding ID: the+browning+version+1994
# Insert of existing embedding ID: bushwhacked+1995
# Insert of existing embedding ID: before+the+rain+1994
# Insert of existing embedding ID: before+sunrise+1995
# Insert of existing embedding ID: billy+madison+1995
# Insert of existing embedding ID: the+babysitter+1995
# Insert of existing embedding ID: boys+on+the+side+1995
# Insert of existing embedding ID: the+cure+1995
# Insert of existing embedding ID: castle+freak+1995
# Insert of existing embedding ID: circle+of+friends+1995
# Insert of existing embedding ID: clerks+1994
# Insert of existing embedding ID: don+juan+demarco+1994
# Insert of existing embedding ID: disclosure+1994
# Insert of existing embedding ID: dream+man+1995
# Insert of existing embedding ID: drop+zone+1994
# Insert of existing embedding ID: destiny+turns+on+the+radio+1995
# Insert of existing embedding ID: death+and+the+maiden+1994
# Insert of existing embedding ID: dolores+claiborne+1995
# Insert of existing embedding ID: dumb+and+dumber+1994
# Insert of existing embedding ID: exotica+1994
# Insert of existing embedding ID: exit+to+eden+1994
# Insert of existing embedding ID: ed+wood+1994
# Insert of existing embedding ID: french+kiss+1995
# Insert of existing embedding ID: forget+paris+1995
# Insert of existing embedding ID: a+goofy+movie+1995
# Insert of existing embedding ID: hideaway+1995
# Insert of existing embedding ID: fluke+1995
# Insert of existing embedding ID: farinelli+1994
# Insert of existing embedding ID: gordy+1995
# Insert of existing embedding ID: the+glass+shield+1994
# Insert of existing embedding ID: hoop+dreams+1994
# Insert of existing embedding ID: heavenly+creatures+1994
# Insert of existing embedding ID: houseguest+1995
# Insert of existing embedding ID: immortal+beloved+1994
# Insert of existing embedding ID: heavyweights+1995
# Insert of existing embedding ID: the+hunted+1995
# Insert of existing embedding ID: i.q.+1994
# Insert of existing embedding ID: interview+with+the+vampire+1994
# Insert of existing embedding ID: jefferson+in+paris+1995
# Insert of existing embedding ID: the+jerky+boys+1995
# Insert of existing embedding ID: junior+1994
# Insert of existing embedding ID: just+cause+1995
# Insert of existing embedding ID: kiss+of+death+1995
# Insert of existing embedding ID: star+wars+1977
# Insert of existing embedding ID: little+women+1994
# Insert of existing embedding ID: a+little+princess+1995
# Insert of existing embedding ID: ladybird+ladybird+1994
# Insert of existing embedding ID: legends+of+the+fall+1994
# Insert of existing embedding ID: major+payne+1995
# Insert of existing embedding ID: little+odessa+1994
# Insert of existing embedding ID: mi+vida+loca+1994
# Insert of existing embedding ID: love+affair+1994
# Insert of existing embedding ID: losing+isaiah+1995
# Insert of existing embedding ID: the+madness+of+king+george+1994
# Insert of existing embedding ID: man+of+the+house+1995
# Insert of existing embedding ID: mixed+nuts+1994
# Insert of existing embedding ID: milk+money+1994
# Insert of existing embedding ID: miracle+on+34th+street+1994
# Insert of existing embedding ID: miami+rhapsody+1995
# Insert of existing embedding ID: my+family+1995
# Insert of existing embedding ID: murder+in+the+first+1995
# Insert of existing embedding ID: nell+1994
# Insert of existing embedding ID: new+jersey+drive+1995
# Insert of existing embedding ID: new+york+cop+1993
# Insert of existing embedding ID: beyond+bedlam+1994
# Insert of existing embedding ID: nemesis+2+-+nebula+1995
# Insert of existing embedding ID: nina+takes+a+lover+1995
# Insert of existing embedding ID: natural+born+killers+1994
# Insert of existing embedding ID: only+you+1994
# Insert of existing embedding ID: once+were+warriors+1994
# Insert of existing embedding ID: outbreak+1995
# Insert of existing embedding ID: the+perez+family+1995
# Insert of existing embedding ID: pulp+fiction+1994
# Insert of existing embedding ID: panther+1995
# Insert of existing embedding ID: pushing+hands+1992
# Insert of existing embedding ID: priest+1994
# Insert of existing embedding ID: quiz+show+1994
# Insert of existing embedding ID: picture+bride+1995
# Insert of existing embedding ID: the+quick+and+the+dead+1995
# Insert of existing embedding ID: roommates+1995
# Insert of existing embedding ID: rent-a-kid+1995
# Insert of existing embedding ID: relative+fear+1995
# Insert of existing embedding ID: stuart+saves+his+family+1995
# Insert of existing embedding ID: the+swan+princess+1994
# Insert of existing embedding ID: the+secret+of+roan+inish+1994
# Insert of existing embedding ID: the+specialist+1994
# Insert of existing embedding ID: stargate+1994
# Insert of existing embedding ID: the+santa+clause+1994
# Insert of existing embedding ID: the+shawshank+redemption+1994
# Insert of existing embedding ID: shallow+grave+1994
# Insert of existing embedding ID: suture+1993
# Insert of existing embedding ID: swimming+with+sharks+1994
# Insert of existing embedding ID: the+sum+of+us+1994
# Insert of existing embedding ID: senior+trip+1995
# Insert of existing embedding ID: tank+girl+1995
# Insert of existing embedding ID: tales+from+the+hood+1995
# Insert of existing embedding ID: village+of+the+damned+1995
# Insert of existing embedding ID: tommy+boy+1995
# Insert of existing embedding ID: vanya+on+42nd+street+1994
# Insert of existing embedding ID: the+underneath+1995
# Insert of existing embedding ID: the+walking+dead+1995
# Insert of existing embedding ID: virtuosity+1995
# Insert of existing embedding ID: while+you+were+sleeping+1995
# Insert of existing embedding ID: the+war+1994
# Insert of existing embedding ID: double+happiness+1994
# Insert of existing embedding ID: the+baby-sitters+club+1995
# Insert of existing embedding ID: backbeat+1994
# Insert of existing embedding ID: bitter+moon+1992
# Insert of existing embedding ID: bullets+over+broadway+1994
# Insert of existing embedding ID: clear+and+present+danger+1994
# Insert of existing embedding ID: the+client+1994
# Insert of existing embedding ID: crooklyn+1994
# Insert of existing embedding ID: the+crow+1994
# Insert of existing embedding ID: cobb+1994
# Insert of existing embedding ID: the+flintstones+1994
# Insert of existing embedding ID: forrest+gump+1994
# Insert of existing embedding ID: four+weddings+and+a+funeral+1994
# Insert of existing embedding ID: higher+learning+1995
# Insert of existing embedding ID: i+like+it+like+that+1994
# Insert of existing embedding ID: i+love+trouble+1994
# Insert of existing embedding ID: it+could+happen+to+you+1994
# Insert of existing embedding ID: the+jungle+book+1994
# Insert of existing embedding ID: the+lion+king+1994
# Insert of existing embedding ID: little+buddha+1993
# Insert of existing embedding ID: new+nightmare+1994
# Insert of existing embedding ID: the+mask+1994
# Insert of existing embedding ID: maverick+1994
# Insert of existing embedding ID: mrs.+parker+and+the+vicious+circle+1994
# Insert of existing embedding ID: the+paper+1994
# Insert of existing embedding ID: reality+bites+1994
# Insert of existing embedding ID: red+rock+west+1993
# Insert of existing embedding ID: safe+passage+1994
# Insert of existing embedding ID: the+river+wild+1994
# Insert of existing embedding ID: speed+1994
# Insert of existing embedding ID: speechless+1994
# Insert of existing embedding ID: timecop+1994
# Insert of existing embedding ID: true+lies+1994
# Insert of existing embedding ID: when+a+man+loves+a+woman+1994
# Insert of existing embedding ID: wolf+1994
# Insert of existing embedding ID: wyatt+earp+1994
# Insert of existing embedding ID: bad+company+1995
# Insert of existing embedding ID: a+man+of+no+importance+1994
# Insert of existing embedding ID: s.f.w.+1994
# Insert of existing embedding ID: a+low+down+dirty+shame+1994
# Insert of existing embedding ID: the+secret+adventures+of+tom+thumb+1993
# Insert of existing embedding ID: street+fighter+1994
# Insert of existing embedding ID: coldblooded+1995
# Insert of existing embedding ID: desert+winds+1997
# Insert of existing embedding ID: fall+time+1995
# Insert of existing embedding ID: the+fear+1995
# Insert of existing embedding ID: frank+and+ollie+1995
# Insert of existing embedding ID: girl+in+the+cadillac+1995
# Insert of existing embedding ID: homage+1995
# Insert of existing embedding ID: mirage+1995
# Insert of existing embedding ID: open+season+1996
# Insert of existing embedding ID: federal+hill+1995
# Insert of existing embedding ID: in+the+mouth+of+madness+1994
# Insert of existing embedding ID: 8+seconds+1994
# Insert of existing embedding ID: above+the+rim+1994
# Insert of existing embedding ID: addams+family+values+1993
# Insert of existing embedding ID: the+age+of+innocence+1993
# Insert of existing embedding ID: airheads+1994
# Insert of existing embedding ID: the+air+up+there+1994
# Insert of existing embedding ID: another+stakeout+1993
# Insert of existing embedding ID: bad+girls+1994
# Insert of existing embedding ID: barcelona+1994
# Insert of existing embedding ID: being+human+1994
# Insert of existing embedding ID: the+beverly+hillbillies+1993
# Insert of existing embedding ID: beverly+hills+cop+iii+1994
# Insert of existing embedding ID: black+beauty+1994
# Insert of existing embedding ID: blink+1994
# Insert of existing embedding ID: blown+away+1994
# Insert of existing embedding ID: blue+chips+1994
# Insert of existing embedding ID: blue+sky+1994
# Insert of existing embedding ID: body+snatchers+1993
# Insert of existing embedding ID: boxing+helena+1993
# Insert of existing embedding ID: a+bronx+tale+1993
# Insert of existing embedding ID: cabin+boy+1994
# Insert of existing embedding ID: calendar+girl+1993
# Insert of existing embedding ID: clean+slate+1994
# Insert of existing embedding ID: cliffhanger+1993
# Insert of existing embedding ID: coneheads+1993
# Insert of existing embedding ID: color+of+night+1994
# Insert of existing embedding ID: the+cowboy+way+1994
# Insert of existing embedding ID: dangerous+game+1993
# Insert of existing embedding ID: dave+1993
# Insert of existing embedding ID: dazed+and+confused+1993
# Insert of existing embedding ID: demolition+man+1993
# Insert of existing embedding ID: the+endless+summer+2+1994
# Insert of existing embedding ID: even+cowgirls+get+the+blues+1994
# Insert of existing embedding ID: fatal+instinct+1993
# Insert of existing embedding ID: the+favor+1994
# Insert of existing embedding ID: fearless+1993
# Insert of existing embedding ID: fear+of+a+black+hat+1994
# Insert of existing embedding ID: with+honors+1994
# Insert of existing embedding ID: flesh+and+bone+1993
# Insert of existing embedding ID: for+love+or+money+1993
# Insert of existing embedding ID: the+firm+1993
# Insert of existing embedding ID: free+willy+1993
# Insert of existing embedding ID: fresh+1994
# Insert of existing embedding ID: the+fugitive+1993
# Insert of existing embedding ID: the+getaway+1994
# Insert of existing embedding ID: getting+even+with+dad+1994
# Insert of existing embedding ID: go+fish+1994
# Insert of existing embedding ID: a+good+man+in+africa+1994
# Insert of existing embedding ID: guilty+as+sin+1993
# Insert of existing embedding ID: hard+target+1993
# Insert of existing embedding ID: live+nude+girls+1995
# Insert of existing embedding ID: the+englishman+who+went+up+a+hill+but+came+down+a+mountain+1995
# Insert of existing embedding ID: the+house+of+the+spirits+1993
# Insert of existing embedding ID: house+party+3+1994
# Insert of existing embedding ID: the+hudsucker+proxy+1994
# Insert of existing embedding ID: in+the+army+now+1994
# Insert of existing embedding ID: in+the+line+of+fire+1993
# Insert of existing embedding ID: in+the+name+of+the+father+1993
# Insert of existing embedding ID: the+inkwell+1994
# Insert of existing embedding ID: jimmy+hollywood+1994
# Insert of existing embedding ID: judgment+night+1993
# Insert of existing embedding ID: jurassic+park+1993
# Insert of existing embedding ID: kalifornia+1993
# Insert of existing embedding ID: killing+zoe+1993
# Insert of existing embedding ID: king+of+the+hill+1993
# Insert of existing embedding ID: lassie+1994
# Insert of existing embedding ID: last+action+hero+1993
# Insert of existing embedding ID: life+with+mikey+1993
# Insert of existing embedding ID: lightning+jack+1994
# Insert of existing embedding ID: m.+butterfly+1993
# Insert of existing embedding ID: made+in+america+1993
# Insert of existing embedding ID: malice+1993
# Insert of existing embedding ID: the+man+without+a+face+1993
# Insert of existing embedding ID: manhattan+murder+mystery+1993
# Insert of existing embedding ID: menace+ii+society+1993
# Insert of existing embedding ID: executive+decision+1996
# Insert of existing embedding ID: what+happened+was...+1994
# Insert of existing embedding ID: much+ado+about+nothing+1993
# Insert of existing embedding ID: mr.+jones+1993
# Insert of existing embedding ID: mr.+wonderful+1993
# Insert of existing embedding ID: mrs.+doubtfire+1993
# Insert of existing embedding ID: naked+1993
# Insert of existing embedding ID: the+next+karate+kid+1994
# Insert of existing embedding ID: the+new+age+1994
# Insert of existing embedding ID: no+escape+1994
# Insert of existing embedding ID: north+1994
# Insert of existing embedding ID: orlando+1992
# Insert of existing embedding ID: a+perfect+world+1993
# Insert of existing embedding ID: philadelphia+1993
# Insert of existing embedding ID: the+piano+1993
# Insert of existing embedding ID: poetic+justice+1993
# Insert of existing embedding ID: the+program+1993
# Insert of existing embedding ID: the+puppet+masters+1994
# Insert of existing embedding ID: radioland+murders+1994
# Insert of existing embedding ID: the+ref+1994
# Insert of existing embedding ID: the+remains+of+the+day+1993
# Insert of existing embedding ID: renaissance+man+1994
# Insert of existing embedding ID: rising+sun+1993
# Insert of existing embedding ID: the+road+to+wellville+1994
# Insert of existing embedding ID: robocop+3+1993
# Insert of existing embedding ID: romeo+is+bleeding+1993
# Insert of existing embedding ID: romper+stomper+1992
# Insert of existing embedding ID: ruby+in+paradise+1993
# Insert of existing embedding ID: rudy+1993
# Insert of existing embedding ID: the+saint+of+fort+washington+1993
# Insert of existing embedding ID: the+scout+1994
# Insert of existing embedding ID: searching+for+bobby+fischer+1993
# Insert of existing embedding ID: second+best+1994
# Insert of existing embedding ID: the+secret+garden+1993
# Insert of existing embedding ID: serial+mom+1994
# Insert of existing embedding ID: the+shadow+1994
# Insert of existing embedding ID: shadowlands+1993
# Insert of existing embedding ID: short+cuts+1993
# Insert of existing embedding ID: a+simple+twist+of+fate+1994
# Insert of existing embedding ID: sirens+1993
# Insert of existing embedding ID: six+degrees+of+separation+1993
# Insert of existing embedding ID: sleepless+in+seattle+1993
# Insert of existing embedding ID: sliver+1993
# Insert of existing embedding ID: blade+runner+1982
# Insert of existing embedding ID: son+in+law+1993
# Insert of existing embedding ID: so+i+married+an+axe+murderer+1993
# Insert of existing embedding ID: striking+distance+1993
# Insert of existing embedding ID: harem+1985
# Insert of existing embedding ID: super+mario+bros.+1993
# Insert of existing embedding ID: surviving+the+game+1994
# Insert of existing embedding ID: terminal+velocity+1994
# Insert of existing embedding ID: thirty+two+short+films+about+glenn+gould+1993
# Insert of existing embedding ID: threesome+1994
# Insert of existing embedding ID: the+nightmare+before+christmas+1993
# Insert of existing embedding ID: the+three+musketeers+1993
# Insert of existing embedding ID: tombstone+1993
# Insert of existing embedding ID: trial+by+jury+1994
# Insert of existing embedding ID: true+romance+1993
# Insert of existing embedding ID: the+war+room+1993
# Insert of existing embedding ID: the+pagemaster+1994
# Insert of existing embedding ID: killer+1994
# Insert of existing embedding ID: welcome+to+the+dollhouse+1995
# Insert of existing embedding ID: germinal+1993
# Insert of existing embedding ID: chasers+1994
# Insert of existing embedding ID: cronos+1993
# Insert of existing embedding ID: naked+in+new+york+1993
# Insert of existing embedding ID: kika+1993
# Insert of existing embedding ID: bhaji+on+the+beach+1994
# Insert of existing embedding ID: little+big+league+1994
# Insert of existing embedding ID: wide+eyed+and+legless+1993
# Insert of existing embedding ID: foreign+student+1994
# Insert of existing embedding ID: spanking+the+monkey+1994
# Insert of existing embedding ID: the+little+rascals+1994
# Insert of existing embedding ID: andre+1994
# Insert of existing embedding ID: princess+caraboo+1994
# Insert of existing embedding ID: the+celluloid+closet+1996
# Insert of existing embedding ID: the+brady+bunch+movie+1995
# Insert of existing embedding ID: home+alone+1990
# Insert of existing embedding ID: ghost+1990
# Insert of existing embedding ID: aladdin+1992
# Insert of existing embedding ID: dances+with+wolves+1990
# Insert of existing embedding ID: tough+and+deadly+1995
# Insert of existing embedding ID: batman+1989
# Insert of existing embedding ID: the+silence+of+the+lambs+1991
# Insert of existing embedding ID: snow+white+and+the+seven+dwarfs+1937
# Insert of existing embedding ID: beauty+and+the+beast+1991
# Insert of existing embedding ID: pinocchio+1940
# Insert of existing embedding ID: pretty+woman+1990
# Insert of existing embedding ID: the+wild+bunch+1969
# Insert of existing embedding ID: love+and+a+.45+1994
# Insert of existing embedding ID: a+great+day+in+harlem+1994
# Insert of existing embedding ID: bye+bye+love+1995
# Insert of existing embedding ID: one+fine+day+1996
# Insert of existing embedding ID: century+1993
# Insert of existing embedding ID: fargo+1996
# Insert of existing embedding ID: heavy+metal+1981
# Insert of existing embedding ID: the+pallbearer+1996
# Insert of existing embedding ID: jane+eyre+1996
# Insert of existing embedding ID: loaded+1996
# Insert of existing embedding ID: the+aristocats+1970
# Insert of existing embedding ID: two+much+1996
# Insert of existing embedding ID: ed+1996
# Insert of existing embedding ID: a+modern+affair+1996
# Insert of existing embedding ID: condition+red+1995
# Insert of existing embedding ID: a+thin+line+between+love+and+hate+1996
# Insert of existing embedding ID: the+last+supper+1995
# Insert of existing embedding ID: primal+fear+1996
# Insert of existing embedding ID: rude+1995
# Insert of existing embedding ID: carried+away+1996
# Insert of existing embedding ID: all+dogs+go+to+heaven+2+1996
# Insert of existing embedding ID: land+and+freedom+1995
# Insert of existing embedding ID: denise+calls+up+1995
# Insert of existing embedding ID: theodore+rex+1995
# Insert of existing embedding ID: a+family+thing+1996
# Insert of existing embedding ID: frisk+1996
# Insert of existing embedding ID: sgt.+bilko+1996
# Insert of existing embedding ID: girl+6+1996
# Insert of existing embedding ID: diabolique+1996
# Insert of existing embedding ID: happy+weekend+1996
# Insert of existing embedding ID: courage+under+fire+1996
# Insert of existing embedding ID: moll+flanders+1996
# Insert of existing embedding ID: dragonheart+1996
# Insert of existing embedding ID: und+keiner+weint+mir+nach+1996
# Insert of existing embedding ID: eddie+1996
# Insert of existing embedding ID: yankee+zulu+1993
# Insert of existing embedding ID: august+1996
# Insert of existing embedding ID: james+and+the+giant+peach+1996
# Insert of existing embedding ID: fear+1996
# Insert of existing embedding ID: faithful+1996
# Insert of existing embedding ID: bloodsport+ii+1996
# Insert of existing embedding ID: tarantella+1996
# Insert of existing embedding ID: space+jam+1996
# Insert of existing embedding ID: barbarella+1968
# Insert of existing embedding ID: hostile+intentions+1995
# Insert of existing embedding ID: they+bite+1996
# Insert of existing embedding ID: some+folks+call+it+a+sling+blade+1994
# Insert of existing embedding ID: the+run+of+the+country+1995
# Insert of existing embedding ID: coup+de+torchon+1981
# Insert of existing embedding ID: windows+1980
# Insert of existing embedding ID: country+life+1994
# Insert of existing embedding ID: operation+dumbo+drop+1995
# Insert of existing embedding ID: mrs.+winterbourne+1996
# Insert of existing embedding ID: solo+1996
# Insert of existing embedding ID: the+substitute+1996
# Insert of existing embedding ID: true+crime+1996
# Insert of existing embedding ID: butterfly+kiss+1995
# Insert of existing embedding ID: feeling+minnesota+1996
# Insert of existing embedding ID: delta+of+venus+1995
# Insert of existing embedding ID: to+cross+the+rubicon+1991
# Insert of existing embedding ID: angus+1995
# Insert of existing embedding ID: faces+1968
# Insert of existing embedding ID: boys+1996
# Insert of existing embedding ID: the+quest+1996
# Insert of existing embedding ID: cosi+1996
# Insert of existing embedding ID: sunset+park+1996
# Insert of existing embedding ID: mulholland+falls+1996
# Insert of existing embedding ID: celtic+pride+1996
# Insert of existing embedding ID: flipper+1996
# Insert of existing embedding ID: captives+1994
# Insert of existing embedding ID: of+love+and+shadows+1994
# Insert of existing embedding ID: dead+man+1995
# Insert of existing embedding ID: switchblade+sisters+1975
# Insert of existing embedding ID: multiplicity+1996
# Insert of existing embedding ID: the+craft+1996
# Insert of existing embedding ID: the+great+white+hype+1996
# Insert of existing embedding ID: last+dance+1996
# Insert of existing embedding ID: cold+comfort+farm+1995
# Insert of existing embedding ID: original+gangstas+1996
# Insert of existing embedding ID: the+rock+1996
# Insert of existing embedding ID: getting+away+with+murder+1996
# Insert of existing embedding ID: twister+1996
# Insert of existing embedding ID: barb+wire+1996
# Insert of existing embedding ID: ghost+in+the+shell+1995
# Insert of existing embedding ID: thinner+1996
# Insert of existing embedding ID: spy+hard+1996
# Insert of existing embedding ID: brothers+in+trouble+1995
# Insert of existing embedding ID: a+close+shave+1995
# Insert of existing embedding ID: force+of+evil+1948
# Insert of existing embedding ID: the+stupids+1996
# Insert of existing embedding ID: the+arrival+1996
# Insert of existing embedding ID: the+man+from+down+under+1943
# Insert of existing embedding ID: careful+1992
# Insert of existing embedding ID: a+month+by+the+lake+1995
# Insert of existing embedding ID: kim+1950
# Insert of existing embedding ID: stalingrad+1993
# Insert of existing embedding ID: the+phantom+1996
# Insert of existing embedding ID: striptease+1996
# Insert of existing embedding ID: the+last+of+the+high+kings+1996
# Insert of existing embedding ID: heavy+1995
# Insert of existing embedding ID: jack+1996
# Insert of existing embedding ID: i+shot+andy+warhol+1996
# Insert of existing embedding ID: the+grass+harp+1995
# Insert of existing embedding ID: quartier+mozart+1992
# Insert of existing embedding ID: babyfever+1994
# Insert of existing embedding ID: trainspotting+1996
# Insert of existing embedding ID: til+there+was+you+1997
# Insert of existing embedding ID: independence+day+1996
# Insert of existing embedding ID: stealing+beauty+1996
# Insert of existing embedding ID: the+fan+1996
# Insert of existing embedding ID: the+hunchback+of+notre+dame+1996
# Insert of existing embedding ID: the+cable+guy+1996
# Insert of existing embedding ID: kingpin+1996
# Insert of existing embedding ID: eraser+1996
# Insert of existing embedding ID: the+gate+of+heavenly+peace+1995
# Insert of existing embedding ID: the+nutty+professor+1996
# Insert of existing embedding ID: somebody+to+love+1994
# Insert of existing embedding ID: a+very+natural+thing+1974
# Insert of existing embedding ID: daylight+1996
# Insert of existing embedding ID: the+frighteners+1996
# Insert of existing embedding ID: lone+star+1996
# Insert of existing embedding ID: harriet+the+spy+1996
# Insert of existing embedding ID: phenomenon+1996
# Insert of existing embedding ID: walking+and+talking+1996
# Insert of existing embedding ID: a+time+to+kill+1996
# Insert of existing embedding ID: american+buffalo+1996
# Insert of existing embedding ID: alaska+1996
# Insert of existing embedding ID: fled+1996
# Insert of existing embedding ID: kazaam+1996
# Insert of existing embedding ID: larger+than+life+1996
# Insert of existing embedding ID: a+boy+called+hate+1996
# Insert of existing embedding ID: power+98+1996
# Insert of existing embedding ID: two+deaths+1995
# Insert of existing embedding ID: a+very+brady+sequel+1996
# Insert of existing embedding ID: stefano+quantestorie+1993
# Insert of existing embedding ID: hedd+wyn+1992
# Insert of existing embedding ID: la+collectionneuse+1967
# Insert of existing embedding ID: kaspar+hauser+1993
# Insert of existing embedding ID: diebinnen+1996
# Insert of existing embedding ID: the+adventures+of+pinocchio+1996
# Insert of existing embedding ID: the+first+wives+club+1996
# Insert of existing embedding ID: stonewall+1995
# Insert of existing embedding ID: ransom+1996
# Insert of existing embedding ID: high+school+high+1996
# Insert of existing embedding ID: phat+beach+1996
# Insert of existing embedding ID: foxfire+1996
# Insert of existing embedding ID: chain+reaction+1996
# Insert of existing embedding ID: matilda+1996
# Insert of existing embedding ID: house+arrest+1996
# Insert of existing embedding ID: bordello+of+blood+1996
# Insert of existing embedding ID: lotto+land+1995
# Insert of existing embedding ID: the+story+of+xinghua+1994
# Insert of existing embedding ID: flirt+1995
# Insert of existing embedding ID: the+big+squeeze+1996
# Insert of existing embedding ID: the+spitfire+grill+1996
# Insert of existing embedding ID: escape+from+l.a.+1996
# Insert of existing embedding ID: basquiat+1996
# Insert of existing embedding ID: tin+cup+1996
# Insert of existing embedding ID: dingo+1991
# Insert of existing embedding ID: mille+bolle+blu+1993
# Insert of existing embedding ID: the+godfather+1972
# Insert of existing embedding ID: small+faces+1996
# Insert of existing embedding ID: bound+1996
# Insert of existing embedding ID: carpool+1996
# Insert of existing embedding ID: death+in+brunswick+1990
# Insert of existing embedding ID: kansas+city+1996
# Insert of existing embedding ID: nothing+to+lose+1994
# Insert of existing embedding ID: girls+town+1996
# Insert of existing embedding ID: bye-bye+1995
# Insert of existing embedding ID: the+relic+1997
# Insert of existing embedding ID: the+island+of+dr.+moreau+1996
# Insert of existing embedding ID: first+kid+1996
# Insert of existing embedding ID: the+trigger+effect+1996
# Insert of existing embedding ID: sweet+nothing+1995
# Insert of existing embedding ID: bogus+1996
# Insert of existing embedding ID: bulletproof+1996
# Insert of existing embedding ID: talk+of+angels+1998
# Insert of existing embedding ID: baton+rouge+1988
# Insert of existing embedding ID: twelfth+night+1996
# Insert of existing embedding ID: mother+night+1996
# Insert of existing embedding ID: liebelei+1933
# Insert of existing embedding ID: for+whom+the+bell+tolls+1943
# Insert of existing embedding ID: the+philadelphia+story+1940
# Insert of existing embedding ID: an+american+in+paris+1951
# Insert of existing embedding ID: funny+face+1957
# Insert of existing embedding ID: vertigo+1958
# Insert of existing embedding ID: rear+window+1954
# Insert of existing embedding ID: it+happened+one+night+1934
# Insert of existing embedding ID: gaslight+1944
# Insert of existing embedding ID: the+gay+divorcee+1934
# Insert of existing embedding ID: north+by+northwest+1959
# Insert of existing embedding ID: the+apartment+1960
# Insert of existing embedding ID: some+like+it+hot+1959
# Insert of existing embedding ID: charade+1963
# Insert of existing embedding ID: casablanca+1942
# Insert of existing embedding ID: the+maltese+falcon+1941
# Insert of existing embedding ID: my+fair+lady+1964
# Insert of existing embedding ID: sabrina+1954
# Insert of existing embedding ID: roman+holiday+1953
# Insert of existing embedding ID: the+little+princess+1939
# Insert of existing embedding ID: meet+me+in+st.+louis+1944
# Insert of existing embedding ID: the+wizard+of+oz+1939
# Insert of existing embedding ID: gone+with+the+wind+1939
# Insert of existing embedding ID: my+favorite+year+1982
# Insert of existing embedding ID: sunset+boulevard+1950
# Insert of existing embedding ID: citizen+kane+1941
# Insert of existing embedding ID: golden+earrings+1947
# Insert of existing embedding ID: all+about+eve+1950
# Insert of existing embedding ID: the+women+1939
# Insert of existing embedding ID: rebecca+1940
# Insert of existing embedding ID: foreign+correspondent+1940
# Insert of existing embedding ID: notorious+1946
# Insert of existing embedding ID: spellbound+1945
# Insert of existing embedding ID: an+affair+to+remember+1957
# Insert of existing embedding ID: to+catch+a+thief+1955
# Insert of existing embedding ID: father+of+the+bride+1950
# Insert of existing embedding ID: the+band+wagon+1953
# Insert of existing embedding ID: ninotchka+1939
# Insert of existing embedding ID: love+in+the+afternoon+1957
# Insert of existing embedding ID: gigi+1958
# Insert of existing embedding ID: the+reluctant+debutante+1958
# Insert of existing embedding ID: the+adventures+of+robin+hood+1938
# Insert of existing embedding ID: the+mark+of+zorro+1940
# Insert of existing embedding ID: laura+1944
# Insert of existing embedding ID: the+ghost+and+mrs.+muir+1947
# Insert of existing embedding ID: lost+horizon+1937
# Insert of existing embedding ID: top+hat+1935
# Insert of existing embedding ID: to+be+or+not+to+be+1942
# Insert of existing embedding ID: my+man+godfrey+1936
# Insert of existing embedding ID: giant+1956
# Insert of existing embedding ID: east+of+eden+1955
# Insert of existing embedding ID: the+thin+man+1934
# Insert of existing embedding ID: his+girl+friday+1940
# Insert of existing embedding ID: around+the+world+in+eighty+days+1956
# Insert of existing embedding ID: mr.+smith+goes+to+washington+1939
# Insert of existing embedding ID: bringing+up+baby+1938
# Insert of existing embedding ID: penny+serenade+1941
# Insert of existing embedding ID: the+scarlet+letter+1926
# Insert of existing embedding ID: lady+of+burlesque+1943
# Insert of existing embedding ID: of+human+bondage+1934
# Insert of existing embedding ID: angel+on+my+shoulder+1946
# Insert of existing embedding ID: little+lord+fauntleroy+1936
# Insert of existing embedding ID: they+made+me+a+criminal+1939
# Insert of existing embedding ID: the+inspector+general+1949
# Insert of existing embedding ID: angel+and+the+badman+1947
# Insert of existing embedding ID: the+39+steps+1935
# Insert of existing embedding ID: a+walk+in+the+sun+1945
# Insert of existing embedding ID: the+outlaw+1943
# Insert of existing embedding ID: night+of+the+living+dead+1968
# Insert of existing embedding ID: the+african+queen+1951
# Insert of existing embedding ID: beat+the+devil+1953
# Insert of existing embedding ID: cat+on+a+hot+tin+roof+1958
# Insert of existing embedding ID: the+last+time+i+saw+paris+1954
# Insert of existing embedding ID: meet+john+doe+1941
# Insert of existing embedding ID: algiers+1938
# Insert of existing embedding ID: something+to+sing+about+1937
# Insert of existing embedding ID: a+farewell+to+arms+1932
# Insert of existing embedding ID: moonlight+murder+1936
# Insert of existing embedding ID: nothing+personal+1996
# Insert of existing embedding ID: dangerous+ground+1997
# Insert of existing embedding ID: picnic+1955
# Insert of existing embedding ID: madagascar+skin+1995
# Insert of existing embedding ID: the+pompatus+of+love+1996
# Insert of existing embedding ID: small+wonders+1995
# Insert of existing embedding ID: fly+away+home+1996
# Insert of existing embedding ID: bliss+1997
# Insert of existing embedding ID: grace+of+my+heart+1996
# Insert of existing embedding ID: maximum+risk+1996
# Insert of existing embedding ID: michael+collins+1996
# Insert of existing embedding ID: infinity+1996
# Insert of existing embedding ID: big+night+1996
# Insert of existing embedding ID: last+man+standing+1996
# Insert of existing embedding ID: caught+1996
# Insert of existing embedding ID: set+it+off+1996
# Insert of existing embedding ID: 2+days+in+the+valley+1996
# Insert of existing embedding ID: curdled+1996
# Insert of existing embedding ID: extreme+measures+1996
# Insert of existing embedding ID: the+glimmer+man+1996
# Insert of existing embedding ID: the+chamber+1996
# Insert of existing embedding ID: the+apple+dumpling+gang+1975
# Insert of existing embedding ID: escape+to+witch+mountain+1975
# Insert of existing embedding ID: the+love+bug+1968
# Insert of existing embedding ID: herbie+rides+again+1974
# Insert of existing embedding ID: old+yeller+1957
# Insert of existing embedding ID: the+parent+trap+1961
# Insert of existing embedding ID: pollyanna+1960
# Insert of existing embedding ID: the+shaggy+dog+1959
# Insert of existing embedding ID: swiss+family+robinson+1960
# Insert of existing embedding ID: cool+runnings+1993
# Insert of existing embedding ID: angels+in+the+outfield+1994
# Insert of existing embedding ID: cinderella+1950
# Insert of existing embedding ID: winnie+the+pooh+and+the+blustery+day+1968
# Insert of existing embedding ID: the+three+caballeros+1944
# Insert of existing embedding ID: the+sword+in+the+stone+1963
# Insert of existing embedding ID: so+dear+to+my+heart+1948
# Insert of existing embedding ID: mary+poppins+1964
# Insert of existing embedding ID: dumbo+1941
# Insert of existing embedding ID: bedknobs+and+broomsticks+1971
# Insert of existing embedding ID: alice+in+wonderland+1951
# Insert of existing embedding ID: the+fox+and+the+hound+1981
# Insert of existing embedding ID: freeway+1996
# Insert of existing embedding ID: the+sound+of+music+1965
# Insert of existing embedding ID: die+hard+1988
# Insert of existing embedding ID: the+lawnmower+man+1992
# Insert of existing embedding ID: unhook+the+stars+1996
# Insert of existing embedding ID: synthetic+pleasures+1995
# Insert of existing embedding ID: the+secret+agent+1996
# Insert of existing embedding ID: to+gillian+on+her+37th+birthday+1996
# Insert of existing embedding ID: surviving+picasso+1996
# Insert of existing embedding ID: love+is+all+there+is+1996
# Insert of existing embedding ID: beautiful+thing+1996
# Insert of existing embedding ID: the+long+kiss+goodnight+1996
# Insert of existing embedding ID: the+ghost+and+the+darkness+1996
# Insert of existing embedding ID: looking+for+richard+1996
# Insert of existing embedding ID: trees+lounge+1996
# Insert of existing embedding ID: the+proprietor+1996
# Insert of existing embedding ID: normal+life+1996
# Insert of existing embedding ID: get+on+the+bus+1996
# Insert of existing embedding ID: shadow+conspiracy+1997
# Insert of existing embedding ID: jude+1996
# Insert of existing embedding ID: everyone+says+i+love+you+1996
# Insert of existing embedding ID: swingers+1996
# Insert of existing embedding ID: sleepers+1996
# Insert of existing embedding ID: the+sunchaser+1996
# Insert of existing embedding ID: johns+1996
# Insert of existing embedding ID: aladdin+and+the+king+of+thieves+1996
# Insert of existing embedding ID: the+woman+in+question+1952
# Insert of existing embedding ID: shall+we+dance+1937
# Insert of existing embedding ID: a+damsel+in+distress+1937
# Insert of existing embedding ID: crossfire+1947
# Insert of existing embedding ID: macao+1952
# Insert of existing embedding ID: for+the+moment+1993
# Insert of existing embedding ID: the+innocents+1961
# Insert of existing embedding ID: sleeper+1973
# Insert of existing embedding ID: bananas+1971
# Insert of existing embedding ID: a+fish+called+wanda+1988
# Insert of existing embedding ID: life+of+brian+1979
# Insert of existing embedding ID: the+candidate+1972
# Insert of existing embedding ID: the+great+race+1965
# Insert of existing embedding ID: bonnie+and+clyde+1967
# Insert of existing embedding ID: the+old+man+and+the+sea+1958
# Insert of existing embedding ID: dial+m+for+murder+1954
# Insert of existing embedding ID: madame+butterfly+1995
# Insert of existing embedding ID: dirty+dancing+1987
# Insert of existing embedding ID: reservoir+dogs+1992
# Insert of existing embedding ID: platoon+1986
# Insert of existing embedding ID: basic+instinct+1992
# Insert of existing embedding ID: the+doors+1991
# Insert of existing embedding ID: the+crying+game+1992
# Insert of existing embedding ID: glengarry+glen+ross+1992
# Insert of existing embedding ID: e.t.+the+extra-terrestrial+1982
# Insert of existing embedding ID: the+search+for+one-eye+jimmy+1994
# Insert of existing embedding ID: a+christmas+carol+1938
# Insert of existing embedding ID: days+of+thunder+1990
# Insert of existing embedding ID: top+gun+1986
# Insert of existing embedding ID: american+strays+1996
# Insert of existing embedding ID: rebel+without+a+cause+1955
# Insert of existing embedding ID: a+streetcar+named+desire+1951
# Insert of existing embedding ID: the+leopard+son+1996
# Insert of existing embedding ID: bird+of+prey+1995
# Insert of existing embedding ID: palookaville+1995
# Insert of existing embedding ID: the+associate+1996
# Insert of existing embedding ID: the+funeral+1996
# Insert of existing embedding ID: the+sleepover+2013
# Insert of existing embedding ID: north+star+1996
# Insert of existing embedding ID: drunks+1997
# Insert of existing embedding ID: the+people+vs.+larry+flynt+1996
# Insert of existing embedding ID: glory+daze+1995
# Insert of existing embedding ID: a+perfect+candidate+1996
# Insert of existing embedding ID: on+golden+pond+1981
# Insert of existing embedding ID: the+return+of+the+pink+panther+1975
# Insert of existing embedding ID: drop+dead+fred+1991
# Insert of existing embedding ID: the+abyss+1989
# Insert of existing embedding ID: the+fog+1980
# Insert of existing embedding ID: escape+from+new+york+1981
# Insert of existing embedding ID: the+howling+1981
# Insert of existing embedding ID: jean+de+florette+1986
# Insert of existing embedding ID: private+benjamin+1980
# Insert of existing embedding ID: monty+python+and+the+holy+grail+1975
# Insert of existing embedding ID: hustler+white+1996
# Insert of existing embedding ID: dadetown+1995
# Insert of existing embedding ID: everything+relative+1996
# Insert of existing embedding ID: entertaining+angels+-+the+dorothy+day+story+1996
# Insert of existing embedding ID: snowriders+1996
# Insert of existing embedding ID: when+we+were+kings+1996
# Insert of existing embedding ID: the+wrong+trousers+1993
# Insert of existing embedding ID: faust+1994
# Insert of existing embedding ID: he+walked+by+night+1948
# Insert of existing embedding ID: raw+deal+1948
# Insert of existing embedding ID: t-men+1947
# Insert of existing embedding ID: here+comes+cookie+1935
# Insert of existing embedding ID: love+in+bloom+1935
# Insert of existing embedding ID: six+of+a+kind+1934
# Insert of existing embedding ID: the+ruling+class+1972
# Insert of existing embedding ID: mina+tannenbaum+1994
# Insert of existing embedding ID: the+bloody+child+1996
# Insert of existing embedding ID: dear+god+1996
# Insert of existing embedding ID: bad+moon+1996
# Insert of existing embedding ID: american+dream+1990
# Insert of existing embedding ID: bob+roberts+1992
# Insert of existing embedding ID: delicatessen+1991
# Insert of existing embedding ID: enchanted+april+1991
# Insert of existing embedding ID: paths+of+glory+1957
# Insert of existing embedding ID: the+grifters+1990
# Insert of existing embedding ID: hear+my+song+1991
# Insert of existing embedding ID: the+shooter+1997
# Insert of existing embedding ID: the+english+patient+1996
# Insert of existing embedding ID: mediterraneo+1991
# Insert of existing embedding ID: passion+fish+1992
# Insert of existing embedding ID: strictly+ballroom+1992
# Insert of existing embedding ID: the+thin+blue+line+1988
# Insert of existing embedding ID: paris+is+burning+1990
# Insert of existing embedding ID: up+in+smoke+1978
# Insert of existing embedding ID: the+empire+strikes+back+1980
# ...
# Add of existing embedding ID: my+fair+lady+1964
# Add of existing embedding ID: sabrina+1954
# Add of existing embedding ID: roman+holiday+1953
# Add of existing embedding ID: the+little+princess+1939
# Add of existing embedding ID: meet+me+in+st.+louis+1944
# Add of existing embedding ID: the+wizard+of+oz+1939
# Add of existing embedding ID: gone+with+the+wind+1939
# Add of existing embedding ID: my+favorite+year+1982
# Add of existing embedding ID: sunset+boulevard+1950
# Add of existing embedding ID: citizen+kane+1941
# Add of existing embedding ID: golden+earrings+1947
# Add of existing embedding ID: all+about+eve+1950
# Add of existing embedding ID: the+women+1939
# Add of existing embedding ID: rebecca+1940
# Add of existing embedding ID: foreign+correspondent+1940
# Add of existing embedding ID: notorious+1946
# Add of existing embedding ID: spellbound+1945
# Add of existing embedding ID: an+affair+to+remember+1957
# Add of existing embedding ID: to+catch+a+thief+1955
# Add of existing embedding ID: father+of+the+bride+1950
# Add of existing embedding ID: the+band+wagon+1953
# Add of existing embedding ID: ninotchka+1939
# Add of existing embedding ID: love+in+the+afternoon+1957
# Add of existing embedding ID: gigi+1958
# Add of existing embedding ID: the+reluctant+debutante+1958
# Add of existing embedding ID: the+adventures+of+robin+hood+1938
# Add of existing embedding ID: the+mark+of+zorro+1940
# Add of existing embedding ID: laura+1944
# Add of existing embedding ID: the+ghost+and+mrs.+muir+1947
# Add of existing embedding ID: lost+horizon+1937
# Add of existing embedding ID: top+hat+1935
# Add of existing embedding ID: to+be+or+not+to+be+1942
# Add of existing embedding ID: my+man+godfrey+1936
# Add of existing embedding ID: giant+1956
# Add of existing embedding ID: east+of+eden+1955
# Add of existing embedding ID: the+thin+man+1934
# Add of existing embedding ID: his+girl+friday+1940
# Add of existing embedding ID: around+the+world+in+eighty+days+1956
# Add of existing embedding ID: mr.+smith+goes+to+washington+1939
# Add of existing embedding ID: bringing+up+baby+1938
# Add of existing embedding ID: penny+serenade+1941
# Add of existing embedding ID: the+scarlet+letter+1926
# Add of existing embedding ID: lady+of+burlesque+1943
# Add of existing embedding ID: of+human+bondage+1934
# Add of existing embedding ID: angel+on+my+shoulder+1946
# Add of existing embedding ID: little+lord+fauntleroy+1936
# Add of existing embedding ID: they+made+me+a+criminal+1939
# Add of existing embedding ID: the+inspector+general+1949
# Add of existing embedding ID: angel+and+the+badman+1947
# Add of existing embedding ID: the+39+steps+1935
# Add of existing embedding ID: a+walk+in+the+sun+1945
# Add of existing embedding ID: the+outlaw+1943
# Add of existing embedding ID: night+of+the+living+dead+1968
# Add of existing embedding ID: the+african+queen+1951
# Add of existing embedding ID: beat+the+devil+1953
# Add of existing embedding ID: cat+on+a+hot+tin+roof+1958
# Add of existing embedding ID: the+last+time+i+saw+paris+1954
# Add of existing embedding ID: meet+john+doe+1941
# Add of existing embedding ID: algiers+1938
# Add of existing embedding ID: something+to+sing+about+1937
# Add of existing embedding ID: a+farewell+to+arms+1932
# Add of existing embedding ID: moonlight+murder+1936
# Add of existing embedding ID: nothing+personal+1996
# Add of existing embedding ID: dangerous+ground+1997
# Add of existing embedding ID: picnic+1955
# Add of existing embedding ID: madagascar+skin+1995
# Add of existing embedding ID: the+pompatus+of+love+1996
# Add of existing embedding ID: small+wonders+1995
# Add of existing embedding ID: fly+away+home+1996
# Add of existing embedding ID: bliss+1997
# Add of existing embedding ID: grace+of+my+heart+1996
# Add of existing embedding ID: maximum+risk+1996
# Add of existing embedding ID: michael+collins+1996
# Add of existing embedding ID: infinity+1996
# Add of existing embedding ID: big+night+1996
# Add of existing embedding ID: last+man+standing+1996
# Add of existing embedding ID: caught+1996
# Add of existing embedding ID: set+it+off+1996
# Add of existing embedding ID: 2+days+in+the+valley+1996
# Add of existing embedding ID: curdled+1996
# Add of existing embedding ID: extreme+measures+1996
# Add of existing embedding ID: the+glimmer+man+1996
# Add of existing embedding ID: the+chamber+1996
# Add of existing embedding ID: the+apple+dumpling+gang+1975
# Add of existing embedding ID: escape+to+witch+mountain+1975
# Add of existing embedding ID: the+love+bug+1968
# Add of existing embedding ID: herbie+rides+again+1974
# Add of existing embedding ID: old+yeller+1957
# Add of existing embedding ID: the+parent+trap+1961
# Add of existing embedding ID: pollyanna+1960
# Add of existing embedding ID: the+shaggy+dog+1959
# Add of existing embedding ID: swiss+family+robinson+1960
# Add of existing embedding ID: cool+runnings+1993
# Add of existing embedding ID: angels+in+the+outfield+1994
# Add of existing embedding ID: cinderella+1950
# Add of existing embedding ID: winnie+the+pooh+and+the+blustery+day+1968
# Add of existing embedding ID: the+three+caballeros+1944
# Add of existing embedding ID: the+sword+in+the+stone+1963
# Add of existing embedding ID: so+dear+to+my+heart+1948
# Add of existing embedding ID: mary+poppins+1964
# Add of existing embedding ID: dumbo+1941
# Add of existing embedding ID: bedknobs+and+broomsticks+1971
# Add of existing embedding ID: alice+in+wonderland+1951
# Add of existing embedding ID: the+fox+and+the+hound+1981
# Add of existing embedding ID: freeway+1996
# Add of existing embedding ID: the+sound+of+music+1965
# Add of existing embedding ID: die+hard+1988
# Add of existing embedding ID: the+lawnmower+man+1992
# Add of existing embedding ID: unhook+the+stars+1996
# Add of existing embedding ID: synthetic+pleasures+1995
# Add of existing embedding ID: the+secret+agent+1996
# Add of existing embedding ID: to+gillian+on+her+37th+birthday+1996
# Add of existing embedding ID: surviving+picasso+1996
# Add of existing embedding ID: love+is+all+there+is+1996
# Add of existing embedding ID: beautiful+thing+1996
# Add of existing embedding ID: the+long+kiss+goodnight+1996
# Add of existing embedding ID: the+ghost+and+the+darkness+1996
# Add of existing embedding ID: looking+for+richard+1996
# Add of existing embedding ID: trees+lounge+1996
# Add of existing embedding ID: the+proprietor+1996
# Add of existing embedding ID: normal+life+1996
# Add of existing embedding ID: get+on+the+bus+1996
# Add of existing embedding ID: shadow+conspiracy+1997
# Add of existing embedding ID: jude+1996
# Add of existing embedding ID: everyone+says+i+love+you+1996
# Add of existing embedding ID: swingers+1996
# Add of existing embedding ID: sleepers+1996
# Add of existing embedding ID: the+sunchaser+1996
# Add of existing embedding ID: johns+1996
# Add of existing embedding ID: aladdin+and+the+king+of+thieves+1996
# Add of existing embedding ID: the+woman+in+question+1952
# Add of existing embedding ID: shall+we+dance+1937
# Add of existing embedding ID: a+damsel+in+distress+1937
# Add of existing embedding ID: crossfire+1947
# Add of existing embedding ID: macao+1952
# Add of existing embedding ID: for+the+moment+1993
# Add of existing embedding ID: the+innocents+1961
# Add of existing embedding ID: sleeper+1973
# Add of existing embedding ID: bananas+1971
# Add of existing embedding ID: a+fish+called+wanda+1988
# Add of existing embedding ID: life+of+brian+1979
# Add of existing embedding ID: the+candidate+1972
# Add of existing embedding ID: the+great+race+1965
# Add of existing embedding ID: bonnie+and+clyde+1967
# Add of existing embedding ID: the+old+man+and+the+sea+1958
# Add of existing embedding ID: dial+m+for+murder+1954
# Add of existing embedding ID: madame+butterfly+1995
# Add of existing embedding ID: dirty+dancing+1987
# Add of existing embedding ID: reservoir+dogs+1992
# Add of existing embedding ID: platoon+1986
# Add of existing embedding ID: basic+instinct+1992
# Add of existing embedding ID: the+doors+1991
# Add of existing embedding ID: the+crying+game+1992
# Add of existing embedding ID: glengarry+glen+ross+1992
# Add of existing embedding ID: e.t.+the+extra-terrestrial+1982
# Add of existing embedding ID: the+search+for+one-eye+jimmy+1994
# Add of existing embedding ID: a+christmas+carol+1938
# Add of existing embedding ID: days+of+thunder+1990
# Add of existing embedding ID: top+gun+1986
# Add of existing embedding ID: american+strays+1996
# Add of existing embedding ID: rebel+without+a+cause+1955
# Add of existing embedding ID: a+streetcar+named+desire+1951
# Add of existing embedding ID: the+leopard+son+1996
# Add of existing embedding ID: bird+of+prey+1995
# Add of existing embedding ID: palookaville+1995
# Add of existing embedding ID: the+associate+1996
# Add of existing embedding ID: the+funeral+1996
# Add of existing embedding ID: the+sleepover+2013
# Add of existing embedding ID: north+star+1996
# Add of existing embedding ID: drunks+1997
# Add of existing embedding ID: the+people+vs.+larry+flynt+1996
# Add of existing embedding ID: glory+daze+1995
# Add of existing embedding ID: a+perfect+candidate+1996
# Add of existing embedding ID: on+golden+pond+1981
# Add of existing embedding ID: the+return+of+the+pink+panther+1975
# Add of existing embedding ID: drop+dead+fred+1991
# Add of existing embedding ID: the+abyss+1989
# Add of existing embedding ID: the+fog+1980
# Add of existing embedding ID: escape+from+new+york+1981
# Add of existing embedding ID: the+howling+1981
# Add of existing embedding ID: jean+de+florette+1986
# Add of existing embedding ID: private+benjamin+1980
# Add of existing embedding ID: monty+python+and+the+holy+grail+1975
# Add of existing embedding ID: hustler+white+1996
# Add of existing embedding ID: dadetown+1995
# Add of existing embedding ID: everything+relative+1996
# Add of existing embedding ID: entertaining+angels+-+the+dorothy+day+story+1996
# Add of existing embedding ID: snowriders+1996
# Add of existing embedding ID: when+we+were+kings+1996
# Add of existing embedding ID: the+wrong+trousers+1993
# Add of existing embedding ID: faust+1994
# Add of existing embedding ID: he+walked+by+night+1948
# Add of existing embedding ID: raw+deal+1948
# Add of existing embedding ID: t-men+1947
# Add of existing embedding ID: here+comes+cookie+1935
# Add of existing embedding ID: love+in+bloom+1935
# Add of existing embedding ID: six+of+a+kind+1934
# Add of existing embedding ID: the+ruling+class+1972
# Add of existing embedding ID: mina+tannenbaum+1994
# Add of existing embedding ID: the+bloody+child+1996
# Add of existing embedding ID: dear+god+1996
# Add of existing embedding ID: bad+moon+1996
# Add of existing embedding ID: american+dream+1990
# Add of existing embedding ID: bob+roberts+1992
# Add of existing embedding ID: delicatessen+1991
# Add of existing embedding ID: enchanted+april+1991
# Add of existing embedding ID: paths+of+glory+1957
# Add of existing embedding ID: the+grifters+1990
# Add of existing embedding ID: hear+my+song+1991
# Add of existing embedding ID: the+shooter+1997
# Add of existing embedding ID: the+english+patient+1996
# Add of existing embedding ID: mediterraneo+1991
# Add of existing embedding ID: passion+fish+1992
# Add of existing embedding ID: strictly+ballroom+1992
# Add of existing embedding ID: the+thin+blue+line+1988
# Add of existing embedding ID: paris+is+burning+1990
# Add of existing embedding ID: up+in+smoke+1978
# Add of existing embedding ID: the+empire+strikes+back+1980
# Add of existing embedding ID: the+princess+bride+1987
# Add of existing embedding ID: raiders+of+the+lost+ark+1981
# Add of existing embedding ID: brazil+1985
# Add of existing embedding ID: aliens+1986
# Add of existing embedding ID: 12+angry+men+1957
# Add of existing embedding ID: lawrence+of+arabia+1962
# Add of existing embedding ID: a+clockwork+orange+1971
# Add of existing embedding ID: to+kill+a+mockingbird+1962
# Add of existing embedding ID: apocalypse+now+1979
# Add of existing embedding ID: return+of+the+jedi+1983
# Add of existing embedding ID: the+third+man+1949
# Add of existing embedding ID: goodfellas+1990
# Add of existing embedding ID: alien+1979
# Add of existing embedding ID: army+of+darkness+1992
# Add of existing embedding ID: psycho+1960
# Add of existing embedding ID: the+blues+brothers+1980
# Add of existing embedding ID: full+metal+jacket+1987
# Add of existing embedding ID: a+grand+day+out+1990
# Add of existing embedding ID: henry+v+1989
# Add of existing embedding ID: amadeus+1984
# Add of existing embedding ID: the+quiet+man+1952
# Add of existing embedding ID: once+upon+a+time+in+america+1984
# Add of existing embedding ID: raging+bull+1980
# Add of existing embedding ID: annie+hall+1977
# Add of existing embedding ID: the+right+stuff+1983
# Add of existing embedding ID: das+boot+1981
# Add of existing embedding ID: the+sting+1973
# Add of existing embedding ID: harold+and+maude+1971
# Add of existing embedding ID: trust+1990
# Add of existing embedding ID: local+hero+1983
# Add of existing embedding ID: the+terminator+1984
# Add of existing embedding ID: braindead+1992
# Add of existing embedding ID: glory+1989
# Add of existing embedding ID: manhattan+1979
# Add of existing embedding ID: dead+poets+society+1989
# Add of existing embedding ID: the+graduate+1967
# Add of existing embedding ID: touch+of+evil+1958
# Add of existing embedding ID: the+bridge+on+the+river+kwai+1957
# Add of existing embedding ID: chinatown+1974
# Add of existing embedding ID: the+day+the+earth+stood+still+1951
# Add of existing embedding ID: the+treasure+of+the+sierra+madre+1948
# Add of existing embedding ID: bad+taste+1987
# Add of existing embedding ID: duck+soup+1933
# Add of existing embedding ID: better+off+dead...+1985
# Add of existing embedding ID: the+shining+1980
# Add of existing embedding ID: stand+by+me+1986
# Add of existing embedding ID: m+1931
# Add of existing embedding ID: evil+dead+ii+1987
# Add of existing embedding ID: the+great+escape+1963
# Add of existing embedding ID: the+deer+hunter+1978
# Add of existing embedding ID: diva+1981
# Add of existing embedding ID: groundhog+day+1993
# Add of existing embedding ID: unforgiven+1992
# Add of existing embedding ID: the+manchurian+candidate+1962
# Add of existing embedding ID: pump+up+the+volume+1990
# Add of existing embedding ID: arsenic+and+old+lace+1944
# Add of existing embedding ID: back+to+the+future+1985
# Add of existing embedding ID: fried+green+tomatoes+1991
# Add of existing embedding ID: patton+1970
# Add of existing embedding ID: down+by+law+1986
# Add of existing embedding ID: highlander+1986
# Add of existing embedding ID: cool+hand+luke+1967
# Add of existing embedding ID: cyrano+de+bergerac+1990
# Add of existing embedding ID: young+frankenstein+1974
# Add of existing embedding ID: night+on+earth+1991
# Add of existing embedding ID: the+great+dictator+1940
# Add of existing embedding ID: fantasia+1940
# Add of existing embedding ID: high+noon+1952
# Add of existing embedding ID: the+big+sleep+1946
# Add of existing embedding ID: heathers+1988
# Add of existing embedding ID: somewhere+in+time+1980
# Add of existing embedding ID: ben-hur+1959
# Add of existing embedding ID: this+is+spinal+tap+1984
# Add of existing embedding ID: koyaanisqatsi+1982
# Add of existing embedding ID: some+kind+of+wonderful+1987
# Add of existing embedding ID: indiana+jones+and+the+last+crusade+1989
# Add of existing embedding ID: being+there+1979
# Add of existing embedding ID: gandhi+1982
# Add of existing embedding ID: the+unbearable+lightness+of+being+1988
# Add of existing embedding ID: a+room+with+a+view+1985
# Add of existing embedding ID: real+genius+1985
# Add of existing embedding ID: the+killing+fields+1984
# Add of existing embedding ID: forbidden+planet+1956
# Add of existing embedding ID: field+of+dreams+1989
# Add of existing embedding ID: the+man+who+would+be+king+1975
# Add of existing embedding ID: butch+cassidy+and+the+sundance+kid+1969
# Add of existing embedding ID: when+harry+met+sally...+1989
# Add of existing embedding ID: i+shot+a+man+in+vegas+1996
# Add of existing embedding ID: parallel+sons+1995
# Add of existing embedding ID: santa+with+muscles+1996
# Add of existing embedding ID: female+perversions+1996
# Add of existing embedding ID: mad+dog+time+1996
# Add of existing embedding ID: breathing+room+1996
# Add of existing embedding ID: paris+was+a+woman+1996

# %%
movies.count()
# Out:
# 17618

# %%
# To test
i = 4   # Movie 0 is Toy Story, 1 is Jumanji, 4 is Father of the Bride Part II
print(jsons[i])
start = time.time()
movies.query(
    query_texts=[jsons[i]],
    n_results=10,
)
print("Time taken: ", time.time() - start)
# Averages roughly 0.045 seconds per query
# Out:
# {'adult': False, 'belongs_to_collection': "{'id': 96871, 'name': 'Father of the Bride Collection', 'poster_path': '/nts4iOmNnq7GNicycMJ9pSAn204.jpg', 'backdrop_path': '/7qwE57OVZmMJChBpLEbJEmzUydk.jpg'}", 'budget': 0, 'genres': "[{'id': 35, 'name': 'Comedy'}]", 'homepage': nan, 'id': 11862, 'imdb_id': 'tt0113041', 'original_language': 'en', 'original_title': 'Father of the Bride Part II', 'overview': "Just when George Banks has recovered from his daughter's wedding, he receives the news that she's pregnant ... and that George's wife, Nina, is expecting too. He was planning on selling their home, but that's a plan that -- like George -- will have to change with the arrival of both a grandchild and a kid of his own.", 'popularity': 8.387519, 'poster_path': '/e64sOI48hQXyru7naBFyssKFxVd.jpg', 'production_companies': "[{'name': 'Sandollar Productions', 'id': 5842}, {'name': 'Touchstone Pictures', 'id': 9195}]", 'production_countries': "[{'iso_3166_1': 'US', 'name': 'United States of America'}]", 'release_date': '1995-02-10', 'revenue': 76578911.0, 'runtime': 106.0, 'spoken_languages': "[{'iso_639_1': 'en', 'name': 'English'}]", 'status': 'Released', 'tagline': "Just When His World Is Back To Normal... He's In For The Surprise Of His Life!", 'title': 'Father of the Bride Part II', 'video': False, 'vote_average': 5.7, 'vote_count': 173.0, 'movie_id': 'father+of+the+bride+part+ii+1995'}
# Time taken:  0.04439997673034668
